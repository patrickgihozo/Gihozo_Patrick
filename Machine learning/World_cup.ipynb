# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import (
    accuracy_score,
    confusion_matrix,
    classification_report
)

# %%
df = pd.read_csv("C:/Users/User/Documents/world_cup_2026_matches.csv")
print(df.columns.tolist())
# Out:
# ['MatchID', 'Date', 'Stage', 'Group', 'Venue', 'HomeTeam', 'AwayTeam', 'HomeGoals', 'AwayGoals', 'Winner', 'GoalDifference', 'HomeShots', 'AwayShots', 'HomeShotsOnTarget', 'AwayShotsOnTarget', 'HomePossession', 'AwayPossession', 'HomePassAccuracy', 'AwayPassAccuracy', 'HomeYellowCards', 'AwayYellowCards', 'HomeRedCards', 'AwayRedCards', 'HomeCorners', 'AwayCorners', 'Attendance', 'Referee', 'Advanced']

# %%
encoder = LabelEncoder()

df["HomeTeam"] = encoder.fit_transform(df["HomeTeam"])
df["AwayTeam"] = encoder.fit_transform(df["AwayTeam"])
df["Winner"] = encoder.fit_transform(df["Winner"])

x = df[
    [
        "HomeTeam",
        "AwayTeam",
        "HomeShots",
        "AwayShots",
        "HomePossession",
        "AwayPossession"
    ]
]

y = df["Winner"]

# %%
x_train, x_test, y_train, y_test = train_test_split(
    y,
    test_size=0.20,
    random_state=42
)

model = LogisticRegression(max_iter=1000)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 x_train, x_test, y_train, y_test = train_test_split(
#       2     y,
#       3     test_size=0.20,
#       4     random_state=42
#
# ValueError: not enough values to unpack (expected 4, got 2)

# %%
model.fit(x_train, y_train)
predictions = model.predict(x_test)

accuracy = accuracy_score(y_test, predictions)

print("\nAccuracy")
print(f"{accuracy*100:.2f}%")

print("\nConfusion Matrix")
print(confusion_matrix(y_test, predictions))

print("\nClassification Report")
print(classification_report(y_test, predictions))

# %%
home_team = encoder.transform(["Argentina"])[0]
away_team = encoder.transform(["Portugal"])[0]

new_match = [[
    home_team,
    away_team,
    16,      # Home Shots
    12,      # Away Shots
    60,      # Home Possession
    40       # Away Possession
]]

prediction = model.predict(new_match)

winner = encoder.inverse_transform(prediction)

print("\nPredicted Winner")
print(winner[0])
